# %%
#Importing books from the nltk library
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
#playing with index
text7[193]
# Out:
# 'attention'

# %%
text7.index('attention')
# Out:
# 193

# %%
#slicing of books i.e  list
text7[2:100]
# Out:
# [',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.',
#  'Mr.',
#  'Vinken',
#  'is',
#  'chairman',
#  'of',
#  'Elsevier',
#  'N.V.',
#  ',',
#  'the',
#  'Dutch',
#  'publishing',
#  'group',
#  '.',
#  'Rudolph',
#  'Agnew',
#  ',',
#  '55',
#  'years',
#  'old',
#  'and',
#  'former',
#  'chairman',
#  'of',
#  'Consolidated',
#  'Gold',
#  'Fields',
#  'PLC',
#  ',',
#  'was',
#  'named',
#  '*-1',
#  'a',
#  'nonexecutive',
#  'director',
#  'of',
#  'this',
#  'British',
#  'industrial',
#  'conglomerate',
#  '.',
#  'A',
#  'form',
#  'of',
#  'asbestos',
#  'once',
#  'used',
#  '*',
#  '*',
#  'to',
#  'make',
#  'Kent',
#  'cigarette',
#  'filters',
#  'has',
#  'caused',
#  'a',
#  'high',
#  'percentage',
#  'of',
#  'cancer',
#  'deaths',
#  'among',
#  'a',
#  'group',
#  'of',
#  'workers',
#  'exposed',
#  '*',
#  'to',
#  'it',
#  'more',
#  'than',
# ...

# %%
#unique words i.e words without repetition
books=set(text1)
print(len(books))
print(len(text1))
# Out:
# 19317
# 260819

# %%
#joining or splitting
' '.join(['Monty', 'Python'])
# Out:
# 'Monty Python'

# %%
'Monty Python'.split()
# Out:
# ['Monty', 'Python']

# %%
#playing again here it starts from 2nd last word and traverses to end of list
saying = ['After', 'all', 'is', 'said', 'and', 'done',
          'more', 'is', 'said', 'than', 'done']
tokens = set(saying)
tokens = sorted(tokens)
tokens[-2:]
# Out:
# ['said', 'than']

# %%
tokens
# Out:
# ['After', 'all', 'and', 'done', 'is', 'more', 'said', 'than']

# %%
#Finding the frequency of words in the book
freq=FreqDist(text2)
freq
# Out:
# FreqDist({'[': 3,
#           'Sense': 1,
#           'and': 3350,
#           'Sensibility': 1,
#           'by': 737,
#           'Jane': 1,
#           'Austen': 1,
#           '1811': 1,
#           ']': 1,
#           'CHAPTER': 50,
#           '1': 2,
#           'The': 243,
#           'family': 83,
#           'of': 3565,
#           'Dashwood': 252,
#           'had': 969,
#           'long': 100,
#           'been': 440,
#           'settled': 37,
#           'in': 1904,
#           'Sussex': 9,
#           '.': 3975,
#           'Their': 33,
#           'estate': 19,
#           'was': 1846,
#           'large': 26,
#           ',': 9397,
#           'their': 463,
#           'residence': 7,
#           'at': 806,
#           'Norland': 53,
#           'Park': 22,
#           'the': 3861,
#           'centre': 2,
#           'property': 9,
#           'where': 84,
#           'for': 1234,
#           'many': 98,
#           'generations': 1,
#           'they': 428,
# ...

# %%
#Fine-grained Selection of Words according to the user length choice and requirement from the book
v=set(text1)
lst=[w for w in v if len(w)>15]
lst
# Out:
# ['Physiognomically',
#  'subterraneousness',
#  'physiognomically',
#  'characteristically',
#  'preternaturalness',
#  'superstitiousness',
#  'uncompromisedness',
#  'uncomfortableness',
#  'comprehensiveness',
#  'hermaphroditical',
#  'cannibalistically',
#  'uninterpenetratingly',
#  'circumnavigating',
#  'responsibilities',
#  'irresistibleness',
#  'undiscriminating',
#  'apprehensiveness',
#  'simultaneousness',
#  'circumnavigations',
#  'CIRCUMNAVIGATION',
#  'indispensableness',
#  'indiscriminately',
#  'supernaturalness',
#  'circumnavigation']

# %% [markdown]
# # Collocations and Bigrams

# %% [markdown]
# A collocation is a sequence of words that occur together unusually often. Thus red wine is a collocation, whereas the wine is not. A characteristic of collocations is that they are resistant to substitution with words that have similar senses; for example, maroon wine sounds definitely odd.
#
# To get a handle on collocations, we start off by extracting from a text a list of word pairs, also known as bigrams. This is easily accomplished with the function bigrams():

# %%
list(bigrams(['more','often','loud','try','cry']))
# Out:
# [('more', 'often'), ('often', 'loud'), ('loud', 'try'), ('try', 'cry')]

# %%
#collocations
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %% [markdown]
# # Counting Other Things

# %%
fdist = FreqDist(len(w) for w in text1)
print(fdist)
# Out:
# <FreqDist with 19 samples and 260819 outcomes>

# %%
fdist
# Out:
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
#Visualization of dictionary
import matplotlib.pyplot as plt
plt.bar(list(fdist.keys()),fdist.values(),width=1,color='green')
# Out:
# <Container object of 19 artists>
